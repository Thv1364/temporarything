# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.polynomial.polynomial import polyfit
np.random.seed(23321421)

spelling = np.array([5,3,2,3,1,4,5,3,4,4,5,5,4,5,3,2,4,2,4,2,5,3,5,2,3,4,5,2,2,5,5,2,4,4,5,3,1,1,5,3,0,5,3])
grammar = np.array([4,6,3,3,1,5,4,4,2,6,6,2,3,3,6,3,3,4,4,2,3,3,3,1,6,4,5,4,1,4,4,6,3,5,5,5,3,1,4,5,2,4,5])
fig, ax = plt.subplots()
colors = np.random.rand(len(grammar))
area = (30 * np.random.rand(len(grammar)))**2  # 0 to 15 point radii
m, b = np.polyfit(spelling, grammar, 1)

# adding the regression line to the scatter plot
plt.plot(spelling, m*spelling + b)
plt.scatter(spelling, grammar,s=area, c=colors, alpha=0.25)
ax.set(xlabel='Number of Mistakes Found in ',ylabel='Number of Identified Grammar Errors',title='Number of Identified Spelling Errors vs Number of Identified Grammar Errors')
# either have show or savefig commented
plt.show()
plt.savefig('figure1.png', dpi=3000)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['9th Arial', '9th TNR', '10th Arial', '10th TNR', '11th Arial', '11th TNR', '12th Arial', '12th TNR']
values = [6.5, 7.2, 7.5, 7.5, 7.6666666667, 6.6, 7, 6.83333333333]
#bar_colors = ['tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue']
bar_colors=['red', 'blue']*((len(categories)//2))
# bar_colors.append('magenta')
# bar_colors.append('yellow')

# Create the bar graph
plt.bar(categories, values,color=bar_colors)
#colors = ['skyblue', 'lightcoral'] * (len(categories) // 2) 


# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Sample Bar Graph')
plt.xticks(rotation=45, ha='right') # Rotate labels by 45 degrees and align to the right
plt.tight_layout()
# Display the plot
plt.savefig('figure2.png', dpi=3000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['9th Arial', '9th TNR', '10th Arial', '10th TNR', '11th Arial', '11th TNR', '12th Arial', '12th TNR', 'Total Arial', 'Total TNR']
values = [6.5, 7.2, 7.5, 7.5, 7.6666666667, 6.6, 7, 6.83333333333, 7.35, 7.045454545]
#bar_colors = ['tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue']
bar_colors=['red', 'blue']*((len(categories)//2)-1)
bar_colors.append('magenta')
bar_colors.append('yellow')

# Create the bar graph
plt.bar(categories, values,color=bar_colors)
#colors = ['skyblue', 'lightcoral'] * (len(categories) // 2) 


# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Sample Bar Graph')
plt.xticks(rotation=45, ha='right') # Rotate labels by 45 degrees and align to the right
plt.tight_layout()
# Display the plot
plt.show()
