# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 5)) 
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i],ha='center')

# Sample data
categories = ['9th Arial', '9th TNR', '10th Arial', '10th TNR', '11th Arial', '11th TNR', '12th Arial', '12th TNR']
values = [6.5, 7.2, 7.5, 7.5, 7.67, 6.6, 7, 6.83]
#bar_colors = ['tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue','tab:red', 'tab:blue']
bar_colors=[(0.8,0.8,0.8), (0.2,0.2,0.2)]*((len(categories)//2))
# bar_colors.append('magenta')
# bar_colors.append('yellow')

# Create the bar graph
plt.bar(categories, values,color=bar_colors,edgecolor='black', linewidth=1.6)
#colors = ['skyblue', 'lightcoral'] * (len(categories) // 2) 


# Add labels and title
plt.xlabel('Grades/Font')
plt.ylabel('Number of Mistakes Identified (out of 11)')
plt.title('Arial vs. Times New Roman for Each Grade')
plt.xticks(rotation=45, ha='right') # Rotate labels by 45 degrees and align to the right
#plt.tight_layout()
# Display the plot
add_labels(categories, values)
plt.savefig('figure2.png', dpi=3000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Total, Arial', 'Total, TNR']
values = [7.24, 7.04]

bar_colors=[(0.8,0.8,0.8), (0.2,0.2,0.2)]*((len(categories)//2))

plt.figure(figsize=(5, 5)) 
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i],ha='center')
# Create the bar graph
plt.bar(categories, values,color=bar_colors,edgecolor='black', linewidth=1.6)
#colors = ['skyblue', 'lightcoral'] * (len(categories) // 2) 


# Add labels and title
plt.xlabel('Font')
plt.ylabel('Number of Mistakes Identified (out of 11)')
plt.title('Arial vs. Times New Roman')
plt.xticks(rotation=45, ha='right') # Rotate labels by 45 degrees and align to the right
plt.tight_layout()
add_labels(categories, values)
# Display the plot
plt.savefig('figure4.png', dpi=3000)
plt.show()

# %% [markdown]
# ok now onto sexism

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Female, Arial', 'Female, TNR','Male, Arial', 'Male, TNR']
values = [4.11, 7.4,6.5,6.94]

bar_colors=[(0.8,0.8,0.8), (0.2,0.2,0.2)]*((len(categories)//2))

plt.figure(figsize=(5, 5)) 
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i],ha='center')
# Create the bar graph
plt.bar(categories, values,color=bar_colors,edgecolor='black', linewidth=1.6)
#colors = ['skyblue', 'lightcoral'] * (len(categories) // 2) 


# Add labels and title
plt.xlabel('Font')
plt.ylabel('Number of Mistakes Identified (out of 11)')
plt.title('Arial vs. Times New Roman for each Gender')
plt.xticks(rotation=45, ha='right') # Rotate labels by 45 degrees and align to the right
plt.tight_layout()
add_labels(categories, values)
# Display the plot
plt.savefig('figure5.png', dpi=3000)
plt.show()

# %% [markdown]
# spell

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Arial', 'TNR', 'Total']
values = [3.27, 3.57, 3.42]

bar_colors=[(0.8,0.8,0.8), (0.2,0.2,0.2), (0.5,0.5,0.5)]

plt.figure(figsize=(5, 5)) 
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i],ha='center')
# Create the bar graph
plt.bar(categories, values,color=bar_colors,edgecolor='black', linewidth=1.6)
#colors = ['skyblue', 'lightcoral'] * (len(categories) // 2) 


# Add labels and title
plt.xlabel('Font')
plt.ylabel('Number of Spelling Mistakes Identified (out of 5)')
plt.title('Arial vs. Times New Roman for Spelling')
plt.xticks(rotation=45, ha='right') # Rotate labels by 45 degrees and align to the right
plt.tight_layout()
add_labels(categories, values)
# Display the plot
plt.savefig('figure6.png', dpi=3000)
plt.show()

# %% [markdown]
# grammmmmmaer

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Arial', 'TNR', 'Total']
values = [3.77, 3.67, 3.72]

bar_colors=[(0.8,0.8,0.8), (0.2,0.2,0.2), (0.5,0.5,0.5)]

plt.figure(figsize=(5, 5)) 
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i],ha='center')
# Create the bar graph
plt.bar(categories, values,color=bar_colors,edgecolor='black', linewidth=1.6)
#colors = ['skyblue', 'lightcoral'] * (len(categories) // 2) 


# Add labels and title
plt.xlabel('Font')
plt.ylabel('Number of Grammar Mistakes Identified (out of 6)')
plt.title('Arial vs. Times New Roman for Grammar')
plt.xticks(rotation=45, ha='right') # Rotate labels by 45 degrees and align to the right
plt.tight_layout()
add_labels(categories, values)
# Display the plot
plt.savefig('figure7.png', dpi=3000)
plt.show()
